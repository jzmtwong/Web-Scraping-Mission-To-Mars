# %%
# import dependencies
from splinter import Browser
import pandas as pd
import requests
import os
import time
from bs4 import BeautifulSoup

# %%
#create executable path
url = 'https://mars.nasa.gov/news/'
#create brower visit
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
#taking time to load, so need to sleep
time.sleep(3)

# %% [markdown]
# <h3>NASA Mars News</h3>

# %%
# scape the first/latest Title

news_title = soup.find('div', class_='content_title').find('a').text

print(news_title)
# Out:
# NASA Readies Perseverance Mars Rover's Earthly Twin

# %%
# sanity check
soup.find_all('div')
# Out:
# [<div data-react-cache-id="BrowseHappier-0" data-react-class="BrowseHappier" data-react-props='{"gt":1,"lt":11}'></div>,
#  <div data-react-cache-id="HiPO-0" data-react-class="HiPO" data-react-props="{}"></div>,
#  <div id="main_container">
#  <div id="site_body">
#  <div class="site_header_area">
#  <header class="site_header">
#  <div class="brand_area">
#  <div class="brand1">
#  <a class="nasa_logo" href="http://www.nasa.gov" target="_blank" title="visit nasa.gov">NASA</a>
#  </div>
#  <div class="brand2">
#  <a class="top_logo" href="https://science.nasa.gov/" target="_blank" title="Explore NASA Science">NASA Science</a>
#  <a class="sub_logo" href="/mars-exploration/#" title="Mars">Mars Exploration Program</a>
#  </div>
#  <img alt="" class="print_only print_logo" src="/assets/logo_mars_trio_black@2x.png"/>
#  </div>
#  <a class="visuallyhidden focusable" href="#page">Skip Navigation</a>
#  <div class="right_header_container">
# ...

# %%
# scrape the first Paragraph
#not sure why, but the website had "article teaser body" as the class, but when i pulled the info,
#the class was the one below.  Beats me.
news_p = soup.find('div', class_='rollover_description_inner').text

print(news_p)
# Out:
# Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.

# %% [markdown]
# <h3>JPL Mars Space Images - Featured Image</h3>

# %%
# add url, create variable "featured_image_url", open browser to Chrome

featured_image_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
browser = Browser('chrome')
browser.visit(featured_image_url)

# %%
#parse html with beautiful soup
html_image = browser.html

soup = BeautifulSoup(html_image, 'html.parser')

#get background image from url with style tag
featured_image_url  = soup.find('article')['style'].replace('background-image: url(','').replace(');', '')[1:-1]

#website main page url
main_url = 'https://www.jpl.nasa.gov'

#combined url to get image url
image_url = main_url + featured_image_url

#display image
image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA19046-1920x1200.jpg'

# %% [markdown]
# <h3>Mars Facts</h3>

# %%
#visit mar facts
url = "https://space-facts.com/mars/"
browser.visit(url)

#parse the URL using pandas
tables = pd.read_html(url)

#single out a table
facts_df = tables[1]
#assign the columns added earth value as well for fun
facts_df.columns = ['Description', 'Mars Value','Earth Value']
html_table = facts_df.to_html(table_id="html_tbl_css",justify='left',index=False)
data = facts_df.to_dict(orient='records') 
facts_df
# Out:
#           Description       Mars Value      Earth Value
# 0           Diameter:         6,779 km        12,742 km
# 1               Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 2              Moons:                2                1
# 3  Distance from Sun:   227,943,824 km   149,598,262 km
# 4     Length of Year:   687 Earth days      365.24 days
# 5        Temperature:     -87 to -5 °C      -88 to 58°C

# %%
#reference the table with only Mars facts
fact_df = tables[0]
#assign the columns and formatted table with pandas
fact_df.columns = ['Description', 'Mars Value']
html_table = fact_df.to_html(table_id="html_tbl_css",justify='left',index=False)
data = fact_df.to_dict(orient='records') 
fact_df
# Out:
#             Description                     Mars Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %% [markdown]
# <h3>Mars Hemisphere</h3>

# %%
# Visit hemispheres url
hemispheres_url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
browser.visit(hemispheres_url)

soup = bs(hemispheres_url, 'html.parser')
#taking time to load, so need to sleep
time.sleep(15)

#html browser
hemispheres_html = browser.html
soup = bs(hemispheres_html, 'html.parser')

# retreive all items that contain mars hemispheres information
items = soup.find_all('div', class_='item')

# Create empty list to store hemisphere urls 
hemisphere_image_urls = []

# Store the main url 
hemispheres_main_url = 'https://astrogeology.usgs.gov'

# Loop
for item in items: 
    
    # store title
    title = item.find('h3').text
    
    # store full image url link
    partial_img_url = item.find('a', class_='itemLink product-item')['href']
    
    # visit the image url link 
    browser.visit(hemispheres_main_url + partial_img_url)
    
    # HTML of each hemisphere information url 
    partial_img_html = browser.html
    
    # parse HTML for each url 
    soup = bs( partial_img_html, 'html.parser')
    
    # retrieve full image 
    img_url = hemispheres_main_url + soup.find('img', class_='wide-image')['src']
    
    # create dictionary for each and append to stored list 
    hemisphere_image_urls.append({"title" : title, "img_url" : img_url})
    

# display hemisphere_image_url list
hemisphere_image_url
# Out:
# [{'title': 'Cerberus Hemisphere Enhanced',
#   'img_url': 'https://astrogeology.usgs.gov/cache/images/f5e372a36edfa389625da6d0cc25d905_cerberus_enhanced.tif_full.jpg'},
#  {'title': 'Schiaparelli Hemisphere Enhanced',
#   'img_url': 'https://astrogeology.usgs.gov/cache/images/3778f7b43bbbc89d6e3cfabb3613ba93_schiaparelli_enhanced.tif_full.jpg'},
#  {'title': 'Syrtis Major Hemisphere Enhanced',
#   'img_url': 'https://astrogeology.usgs.gov/cache/images/555e6403a6ddd7ba16ddb0e471cadcf7_syrtis_major_enhanced.tif_full.jpg'},
#  {'title': 'Valles Marineris Hemisphere Enhanced',
#   'img_url': 'https://astrogeology.usgs.gov/cache/images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg'}]
